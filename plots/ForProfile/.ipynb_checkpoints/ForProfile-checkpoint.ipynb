# %%
import FaceFinder
import TreeSampler
# Out:
# proportion: 3.5999999999999996
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-febe9ee580e6> in <module>
#       1 import FaceFinder
# ----> 2 import TreeSampler
#       3
#
# ~\Documents\GitHub\TinyProjects\plots\ForProfile\TreeSampler.py in <module>
#     429             plt.figure()
#     430             nx.draw(graph, pos=nx.get_node_attributes(graph, 'pos'), node_size = 1, width = 1, cmap=plt.get_cmap('jet'))
# --> 431             plt.savefig("./plots/Attractor/" + "Size" + str(m) + "WIDTH" + str(width) + "Bias" + str(diagonal_bias) +  "UnderlyingGraph.png" )
#     432             plt.close()
#     433
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
# ...
