# %%
from EnumeratingConnectedPartitions import *
import time

# %%
graph = nx.grid_graph([3,3,3])

# %%
true_sample = test_rejection_sample(graph, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1406bfe221e0> in <module>
# ----> 1 true_sample = test_rejection_sample(graph, 1)
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in test_rejection_sample(graph, goal)
#     178
#     179     while number < goal:
# --> 180         new = rejection_sample(graph)
#     181
#     182         if new != False:
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in rejection_sample(graph)
#     141
#     142     for e in J:
# --> 143         graph = update_coloring(graph, e)
#     144
#     145     coloring = graph.graph["coloring"]
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in update_coloring(graph, edge)
#      34         if a < b:
#      35             for x in graph.nodes():
# ---> 36                 if coloring[x] == b:
#      37                     coloring[x] = a
#      38         else:
#
# KeyboardInterrupt:

# %%
graph = nx.grid_graph([3,3,2])
a = time.time()
x = number_partitions_backtracking(graph)
print(x)
print("took", time.time() - a)
# Out:
# 97500024
# took 16793.367743492126

# %%
graph = nx.grid_graph([3,2,2])
a = time.time()
x = number_partitions_backtracking(graph)
print(x)
print("took", time.time() - a)
# Out:
# 81224
# took 7.082768201828003

# %%
graph = nx.grid_graph([4,2,2])
a = time.time()
x = number_partitions_backtracking(graph)
print(x)
print("took", time.time() - a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-3347f5112219> in <module>
#       1 graph = nx.grid_graph([4,2,2])
#       2 a = time.time()
# ----> 3 x = number_partitions_backtracking(graph)
#       4 print(x)
#       5 print("took", time.time() - a)
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in number_partitions_backtracking(input_graph)
#      91     graph =  nx.convert_node_labels_to_integers(input_graph)
#      92
# ---> 93     list_of_partitions = backtracking(graph)
#      94     #pruned_list = [x for x in list_of_partitions if x != False]
#      95     counter = 0
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in backtracking(graph)
#      86     in_set = []
#      87     out_set = []
# ---> 88     return back_tracking_recursion(graph, layer, in_set, out_set)
#      89
#      90 def number_partitions_backtracking(input_graph):
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      67     layer += 1
#      68     #A corresponding skip ahead step would go here.
# ---> 69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
#      70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      68     #A corresponding skip ahead step would go here.
#      69     left_tree = back_tracking_recursion(graph, layer, in_set + [processed_edge], out_set, processed_edge, set())
# ---> 70     right_tree = back_tracking_recursion(graph, layer, in_set, out_set + [processed_edge], set(),processed_edge)
#      71
#      72     graph.graph["coloring"] = old_coloring
#
# ~\Documents\GitHub\TinyProjects\ConnectedPartitionSampling\EnumeratingConnectedPartitions.py in back_tracking_recursion(input_graph, layer, in_set, out_set, new_in, new_out)
#      47
#      48     graph = input_graph
# ---> 49     old_coloring = copy.deepcopy(graph.graph["coloring"])
#      50     if new_out != set():
#      51         graph = update_coloring(graph, new_out)
#
# ~\anaconda3\lib\copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~\anaconda3\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# KeyboardInterrupt:
